# %%
from detector import Detector
from PIL import Image
import matplotlib.pyplot as plt 
import torchvision

# %%
detector = Detector('cuda')
# Out:
# Loading pretrained model from ./weights/Resnet50_Final.pth
# remove prefix 'module.'
# Missing keys:0
# Unused checkpoint keys:0
# Used keys:456

# %%
img = Image.open('cropped_face_images/000001face.png')
dets = detector(img)
detector.draw(img, dets)
# Out:
# <PIL.Image.Image image mode=RGB size=93x100 at 0x7F69812DA160>

# %%
# it also supports input as tensor (but it must be one image within [-1,1] )
pil_img = Image.open('cropped_face_images/000002face.png')
img = (torchvision.transforms.functional.to_tensor(pil_img) - 0.5) / 0.5
dets = detector(img)
detector.draw(pil_img, dets)
# Out:
# <PIL.Image.Image image mode=RGB size=87x98 at 0x7F6980AFE0A0>

# %%
pil_img = Image.open('cropped_face_images/000003face.png')
img = (torchvision.transforms.functional.to_tensor(pil_img) - 0.5) / 0.5
dets = detector(img)
detector.draw(pil_img, dets)
# Out:
# <PIL.Image.Image image mode=RGB size=106x124 at 0x7F6A2C0F7430>
